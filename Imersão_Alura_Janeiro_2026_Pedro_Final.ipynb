# %% [markdown]
# Aula 1

# %%
import pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print('Linhas:', linhas)
print('Colunas:', colunas)
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Dicionário de renomeação
novos_nomes = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

# Aplicando renomeação
df.rename(columns=novos_nomes, inplace=True)

# Verificando resultado
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
# O método .value_counts() serve para contar quantas vezes cada valor único aparece em uma coluna.
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
senioridade = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'
}
df['senioridade'] = df['senioridade'].replace(senioridade)
df['senioridade'].value_counts()
# Out:
# senioridade
# senior       77241
# pleno        40465
# junior       12443
# executivo     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'integral',
    'PT': 'parcial',
    'CT': 'contrato',
    'FL': 'freelancer'
}
df['contrato'] = df['contrato'].replace(contrato)
df['contrato'].value_counts()
# Out:
# contrato
# integral      132563
# contrato         394
# parcial          376
# freelancer        16
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'L': 'grande',
    'S': 'pequena',
    'M':	'media'

}
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# media      129561
# grande       3574
# pequena       214
# Name: count, dtype: int64

# %%
mapa_trabalho = {
    0: 'presencial',
    100: 'remoto',
    50: 'hibrido'
}

df['remoto'] = df['remoto'].replace(mapa_trabalho)
df['remoto'].value_counts()
# Out:
# remoto
# presencial    105312
# remoto         27718
# hibrido          319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df.describe(include='object')
# Out:
#        senioridade  contrato           cargo   moeda residencia      remoto  \
# count       133349    133349          133349  133349     133349      133349
# unique           4         4             390      26        102           3
# top         senior  integral  Data Scientist     USD         US  presencial
# freq         77241    132563           17314  126140     119579      105312
#
#        empresa tamanho_empresa
# count   133349          133349
# unique      95               3
# top         US           media
# freq    119641          129561

# %% [markdown]
# Aula 2

# %%
df.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade  contrato                      cargo  salario moeda  \
# 5588    NaN      senior  integral            Product Manager   184500   USD
# 59692   NaN       pleno  integral                   Engineer   110000   USD
# 59710   NaN      junior  integral             Data Scientist   208800   USD
# 59759   NaN      senior  integral          Software Engineer   135000   USD
# 59789   NaN      senior  integral                   Engineer   112000   USD
# 131000  NaN      senior  integral  Machine Learning Engineer   163800   USD
# 131006  NaN      senior  integral     Data Analytics Manager   204500   USD
# 133054  NaN      junior  integral             Data Scientist    40000   USD
# 133281  NaN       pleno  integral  Machine Learning Engineer   180000   PLN
# 133317  NaN       pleno  integral             Data Scientist   130000   USD
#
#            usd residencia      remoto empresa tamanho_empresa
# 5588    184500         US  presencial      US           media
# ...

# %%
# 1. Preenchimento com Valores Derivados (Imputation)
# Para salario: Usar a mediana ou média do salário da mesma categoria, senioridade e país.

# 2. Remover Linhas com Dados Faltantes
# Caso a quantidade de dados nulos seja muito pequena (como neste caso, apenas 5 linhas), você pode simplesmente removê-las.

# 3. Inferência e Preenchimento com Regras de Negócio
# Preencher com base em regras claras.

# %%
import numpy as np

df_salarios = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Diana', 'Eduardo'],
    'salario': [4000, np.nan, 3500, np.nan, 5000]
})

# Preencher com a média salarial
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

# Preencher com a mediana salarial
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome  salario  salario_media  salario_mediana
# 0      Ana   4000.0        4000.00           4000.0
# 1    Bruno      NaN        4166.67           4000.0
# 2   Carlos   3500.0        3500.00           3500.0
# 3    Diana      NaN        4166.67           4000.0
# 4  Eduardo   5000.0        5000.00           5000.0

# %%
df_temperaturas = pd.DataFrame({
    'dia': ['Seg', 'Ter', 'Qua', 'Qui', 'Sex'],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas['preenchido_ffill'] = df_temperaturas['temperatura'].ffill()

df_temperaturas
# Out:
#    dia  temperatura  preenchido_ffill
# 0  Seg         30.0              30.0
# 1  Ter          NaN              30.0
# 2  Qua          NaN              30.0
# 3  Qui         28.0              28.0
# 4  Sex         27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
    'dia': ['Seg', 'Ter', 'Qua', 'Qui', 'Sex'],
    'temperatura': [30, np.nan, np.nan, 28, 27]
})

df_temperaturas['preenchido_bfill'] = df_temperaturas['temperatura'].bfill()

df_temperaturas
# Out:
#    dia  temperatura  preenchido_bfill
# 0  Seg         30.0              30.0
# 1  Ter          NaN              28.0
# 2  Qua          NaN              28.0
# 3  Qui         28.0              28.0
# 4  Sex         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Diana', 'Eduardo'],
    'cidade': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Salvador']
})

df_cidades['cidade_corrigida'] = df_cidades['cidade'].fillna('Não informado')

df_cidades
# Out:
#       nome     cidade cidade_corrigida
# 0      Ana  São Paulo        São Paulo
# 1    Bruno        NaN    Não informado
# 2   Carlos   Curitiba         Curitiba
# 3    Diana        NaN    Não informado
# 4  Eduardo   Salvador         Salvador

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025.0      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025.0      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025.0       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025.0       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025.0      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo = df_limpo.assign(ano=df_limpo['ano'].astype('Int64'))

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df_limpo.to_csv('dados-imersao.csv', index=False)

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa
# 0         US      remoto      US           media
# 1         US      remoto      US           media
# 2         AU  presencial      AU           media
# 3         AU  presencial      AU           media
# 4         US  presencial      US           media

# %%
df['senioridade'].value_counts().plot(kind='bar', title='Distribuição dos níveis de experiência')
# Out:
# <Axes: title={'center': 'Distribuição dos níveis de experiência'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd', estimator='mean')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', estimator='mean')
plt.title('Salário médio por nível de senioridade')
plt.ylabel('Salário médio (USD)')
plt.xlabel('Senioridade')
plt.show()

# %%
df.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# executivo    202027.667813
# senior       172850.003845
# pleno        143041.323489
# junior        99039.040264
# Name: usd, dtype: float64

# %%
ordem = df.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['executivo', 'senior', 'pleno', 'junior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', estimator='mean', order=ordem)
plt.title('Salário médio por nível de senioridade')
plt.ylabel('Salário Médio (USD)')
plt.xlabel('Senioridade')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_limpo['usd'], bins=50, kde=True)
plt.title('Distribuição dos Salários')
plt.xlabel('Salário em USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=df_limpo['usd'])
plt.title('Boxplot dos salários')
plt.xlabel('Salário em USD')
plt.show()

# %%
#Como é a distribuição dos salários de acordo com níveis de senioridade?
senioridade = {
    'SE': 'senior',
    'MI': 'pleno',
    'EN': 'junior',
    'EX': 'executivo'
}
df_limpo['senioridade'] = df_limpo['senioridade'].replace(senioridade)

ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title('Distribuição salarial por nível de experiência')
plt.xlabel('Senioridade')
plt.ylabel('Salário (USD)')
plt.show()

# %%
senioridade = {
'SE': 'senior',
'MI': 'pleno',
'EN': 'junior',
'EX': 'executivo' # Corrected typo from 'excecutivo'
}
df_limpo['senioridade'] = df_limpo['senioridade'].replace(senioridade)

plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade') # Changed data=df to data=df_limpo
plt.title('Distribuição salarial por nível de experiência')
plt.xlabel('Senioridade')
plt.ylabel('Salário (USD)')
plt.show()

# %%
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds = df_ds.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 5))
sns.barplot(x='residencia', y='usd', data=media_ds.head(5))
plt.title('Top 5 Países que com maiores médias salarias para Cientistas de Dados')
plt.xlabel('País')
plt.ylabel('Salário Médio (USD)')
plt.show()

# %%
import plotly.express as px

# %%
# Calcular média salarial
media_senioridade = df.groupby('senioridade')['usd'].mean().reset_index()

# Criar gráfico
fig = px.bar(media_senioridade, x='senioridade', y='usd',
             title='Salário Médio por Nível de Senioridade',
             labels={'senioridade': 'Senioridade', 'usd': 'Salário Médio (USD)'},
             color='senioridade')

fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',
    values='quantidade',
    title='Proporção dos Tipos de Trabalho',
    hole=0.5  # opcional: transforma em donut chart
)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top_cargos = df_limpo.groupby('cargo')['usd'].mean().round(2).sort_values(ascending=False).head().reset_index()
top_cargos
# Out:
#                            cargo       usd
# 0             Research Team Lead  450000.0
# 1  Analytics Engineering Manager  399880.0
# 2         Data Science Tech Lead  375000.0
# 3             Applied AI ML Lead  292500.0
# 4             Head of Applied AI  273875.0

# %%
# Gráfico interativo
fig = px.bar(
    top_cargos,
    x='cargo',
    y='usd',
    title='Top 5 cargos com maiores médias salariais',
    labels={'usd': 'Salário médio (USD)', 'cargo': 'Cargo'}
)
fig.update_layout(xaxis_title='Cargo', yaxis_title='Salário médio (USD)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install pycountry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 54.5 MB/s eta 0:00:00
# ...

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)

# %%
# !pip install streamlit
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

# --- Carregamento dos dados ---
df = pd.read_csv("https://raw.githubusercontent.com/vqrca/dashboard_salarios_dados/refs/heads/main/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"${salario_medio:,.0f}")
col2.metric("Salário máximo", f"${salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 61.9 MB/s eta 0:00:00
# ...
# 2026-01-30 22:15:49.917 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 22:15:50.735 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 22:15:51.008
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-01-30 22:15:51.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 22:15:51.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# O LocalTunnel é uma ferramenta que cria um link público seguro para um serviço rodando localmente,
# permitindo acessar aplicações em localhost pela internet.
# !pip install -q streamlit

# %%
# Criar o arquivo streamlit.py
code = """
import streamlit as st
import pandas as pd
import plotly.express as px

# --- Configuração da Página ---
# Define o título da página, o ícone e o layout para ocupar a largura inteira.
st.set_page_config(
    page_title="Dashboard de Salários na Área de Dados",
    page_icon="📊",
    layout="wide",
)

df = pd.read_csv("C:/Users/caelum/Desktop/imersao/dados-imersao-final.csv")

# --- Barra Lateral (Filtros) ---
st.sidebar.header("🔍 Filtros")

# Filtro de Ano
anos_disponiveis = sorted(df['ano'].unique())
anos_selecionados = st.sidebar.multiselect("Ano", anos_disponiveis, default=anos_disponiveis)

# Filtro de Senioridade
senioridades_disponiveis = sorted(df['senioridade'].unique())
senioridades_selecionadas = st.sidebar.multiselect("Senioridade", senioridades_disponiveis, default=senioridades_disponiveis)

# Filtro por Tipo de Contrato
contratos_disponiveis = sorted(df['contrato'].unique())
contratos_selecionados = st.sidebar.multiselect("Tipo de Contrato", contratos_disponiveis, default=contratos_disponiveis)

# Filtro por Tamanho da Empresa
tamanhos_disponiveis = sorted(df['tamanho_empresa'].unique())
tamanhos_selecionados = st.sidebar.multiselect("Tamanho da Empresa", tamanhos_disponiveis, default=tamanhos_disponiveis)

# --- Filtragem do DataFrame ---
# O dataframe principal é filtrado com base nas seleções feitas na barra lateral.
df_filtrado = df[
    (df['ano'].isin(anos_selecionados)) &
    (df['senioridade'].isin(senioridades_selecionadas)) &
    (df['contrato'].isin(contratos_selecionados)) &
    (df['tamanho_empresa'].isin(tamanhos_selecionados))
]

# --- Conteúdo Principal ---
st.title("🎲 Dashboard de Análise de Salários na Área de Dados")
st.markdown("Explore os dados salariais na área de dados nos últimos anos. Utilize os filtros à esquerda para refinar sua análise.")

# --- Métricas Principais (KPIs) ---
st.subheader("Métricas gerais (Salário anual em USD)")

if not df_filtrado.empty:
    salario_medio = df_filtrado['usd'].mean()
    salario_maximo = df_filtrado['usd'].max()
    total_registros = df_filtrado.shape[0]
    cargo_mais_frequente = df_filtrado["cargo"].mode()[0]
else:
    salario_medio, salario_mediano, salario_maximo, total_registros, cargo_mais_comum = 0, 0, 0, ""

col1, col2, col3, col4 = st.columns(4)
col1.metric("Salário médio", f"áá
{salario_maximo:,.0f}")
col3.metric("Total de registros", f"{total_registros:,}")
col4.metric("Cargo mais frequente", cargo_mais_frequente)

st.markdown("---")

# --- Análises Visuais com Plotly ---
st.subheader("Gráficos")

col_graf1, col_graf2 = st.columns(2)

with col_graf1:
    if not df_filtrado.empty:
        top_cargos = df_filtrado.groupby('cargo')['usd'].mean().nlargest(10).sort_values(ascending=True).reset_index()
        grafico_cargos = px.bar(
            top_cargos,
            x='usd',
            y='cargo',
            orientation='h',
            title="Top 10 cargos por salário médio",
            labels={'usd': 'Média salarial anual (USD)', 'cargo': ''}
        )
        grafico_cargos.update_layout(title_x=0.1, yaxis={'categoryorder':'total ascending'})
        st.plotly_chart(grafico_cargos, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de cargos.")

with col_graf2:
    if not df_filtrado.empty:
        grafico_hist = px.histogram(
            df_filtrado,
            x='usd',
            nbins=30,
            title="Distribuição de salários anuais",
            labels={'usd': 'Faixa salarial (USD)', 'count': ''}
        )
        grafico_hist.update_layout(title_x=0.1)
        st.plotly_chart(grafico_hist, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de distribuição.")

col_graf3, col_graf4 = st.columns(2)

with col_graf3:
    if not df_filtrado.empty:
        remoto_contagem = df_filtrado['remoto'].value_counts().reset_index()
        remoto_contagem.columns = ['tipo_trabalho', 'quantidade']
        grafico_remoto = px.pie(
            remoto_contagem,
            names='tipo_trabalho',
            values='quantidade',
            title='Proporção dos tipos de trabalho',
            hole=0.5
        )
        grafico_remoto.update_traces(textinfo='percent+label')
        grafico_remoto.update_layout(title_x=0.1)
        st.plotly_chart(grafico_remoto, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico dos tipos de trabalho.")

with col_graf4:
    if not df_filtrado.empty:
        df_ds = df_filtrado[df_filtrado['cargo'] == 'Data Scientist']
        media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()
        grafico_paises = px.choropleth(media_ds_pais,
            locations='residencia_iso3',
            color='usd',
            color_continuous_scale='rdylgn',
            title='Salário médio de Cientista de Dados por país',
            labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})
        grafico_paises.update_layout(title_x=0.1)
        st.plotly_chart(grafico_paises, use_container_width=True)
    else:
        st.warning("Nenhum dado para exibir no gráfico de países.")

# --- Tabela de Dados Detalhados ---
st.subheader("Dados Detalhados")
st.dataframe(df_filtrado)
"""

# Escreve o código no arquivo app.py
with open("app.py", "w") as file:
    file.write(code)

print("Arquivo app.py criado com sucesso!")
# Out:
# Arquivo app.py criado com sucesso!

# %%
# !streamlit run /content/app.py &>/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.125.132.56
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)

# %% [markdown]
# Aula 3

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa residencia_iso3
# 0         US      remoto      US           media             USA
# 1         US      remoto      US           media             USA
# 2         AU  presencial      AU           media             AUS
# 3         AU  presencial      AU           media             AUS
# 4         US  presencial      US           media             USA

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title="Distribuição de senioridade")
# Out:
# <Axes: title={'center': 'Distribuição de senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# executivo    202027.667813
# senior       172850.838301
# pleno        143044.845979
# junior        99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=True).index

# %%
ordem
# Out:
# Index(['junior', 'pleno', 'senior', 'executivo'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df_limpo['usd'], bins = 50, kde=True)
plt.title("Distribuição dos salários anuais")
plt.xlabel("Salário em USD")
plt.ylabel("Frequência")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.title("Boxplot Salário")
plt.xlabel("Salário em USD")
plt.show()

# %%
ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade)
plt.title("Boxplot da distribuição por senioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
ordem_senioridade = ['junior', 'pleno', 'senior', 'executivo']

plt.figure(figsize=(8,5))
sns.boxplot(x='senioridade', y='usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title("Boxplot da distribuição por senioridade")
plt.xlabel("Salário em USD")
plt.show()

# %%
import plotly.express as px

# %%
# prompt: Crie um gráfico de média salarial por senioridade em barras usando o plotly

senioridade_media_salario = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(senioridade_media_salario,
             x='senioridade',
             y='usd',
             title='Média Salarial por Senioridade',
             labels={'senioridade': 'Nível de Senioridade', 'usd': 'Média Salarial Anual (USD)'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho'

          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             hole=0.5
          )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             hole=0.5
          )
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa residencia_iso3
# 0         US      remoto      US           media             USA
# 1         US      remoto      US           media             USA
# 2         AU  presencial      AU           media             AUS
# 3         AU  presencial      AU           media             AUS
# 4         US  presencial      US           media             USA

# %%
pip install pycountry
# Out:
# yes
# ...

# %%
import pycountry

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade  contrato               cargo  salario moeda     usd  \
# 0  2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1  2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2  2025       pleno  integral       Data Engineer   158800   USD  158800
# 3  2025       pleno  integral       Data Engineer   139200   USD  139200
# 4  2025      junior  integral       Data Engineer    90000   USD   90000
#
#   residencia      remoto empresa tamanho_empresa residencia_iso3
# 0         US      remoto      US           media             USA
# 1         US      remoto      US           media             USA
# 2         AU  presencial      AU           media             AUS
# 3         AU  presencial      AU           media             AUS
# 4         US  presencial      US           media             USA

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)

# %% [markdown]
# Meus Programas criados por meio deste projeto

# %%
# FUNÇÃO LIMPO
df_limpo.head(50)
# DENTRO DO PARENTESES VOCE PODE POR UM NUMERO QUALQUER PARA PODER EXIBIR A LISTA, NO ENTRETANTO A SEQUENCIA COMEÇA A PARTIR DE 0, ENTÃO O ULTIMO NUMERO DEVERÁ SER N-1
# Out:
#      ano senioridade  contrato               cargo  salario moeda     usd  \
# 0   2025      senior  integral  Solutions Engineer   214000   USD  214000
# 1   2025      senior  integral  Solutions Engineer   136000   USD  136000
# 2   2025       pleno  integral       Data Engineer   158800   USD  158800
# 3   2025       pleno  integral       Data Engineer   139200   USD  139200
# 4   2025      junior  integral       Data Engineer    90000   USD   90000
# 5   2025      junior  integral       Data Engineer    80000   USD   80000
# 6   2025      senior  integral      Data Scientist   185000   USD  185000
# 7   2025      senior  integral      Data Scientist   148000   USD  148000
# 8   2025       pleno  integral      Data Scientist   135000   USD  135000
# 9   2025       pleno  integral      Data Scientist   108000   USD  108000
# 10  2025       pleno  integral        BI Developer   118000   USD  118000
# 11  2025       pleno  integral        BI Developer    51000   USD   51000
# ...

# %%
# MEU CÓDIGO: Nele ele pegará apenas o primerio dado e reproduzir nas colunas superiores neste caso os tres primeiros dias usaram os dados da quinta-feira
df_temperaturas = pd.DataFrame({
    'dia': ['Seg', 'Ter', 'Qua', 'Qui', 'Sex','Sab'],
    'temperatura': [np.nan, np.nan, np.nan, 28, 27,26]
})

df_temperaturas['preenchido_bfill'] = df_temperaturas['temperatura'].bfill()

df_temperaturas
# Out:
#    dia  temperatura  preenchido_bfill
# 0  Seg          NaN              28.0
# 1  Ter          NaN              28.0
# 2  Qua          NaN              28.0
# 3  Qui         28.0              28.0
# 4  Sex         27.0              27.0
# 5  Sab         26.0              26.0

# %%
# MEU CÓDIGO, NESTE EXEMPLO A TEMPERATÚRA DE SEGUNDA-FEIRA FICA NULO, OU SEJA SEM DADOS, ou seja ele só ficará com dados preenchidos apenas na quarta-feira
df_temperaturas = pd.DataFrame({
    'dia': ['Seg', 'Ter', 'Qua', 'Qui', 'Sex','Sab'],
    'temperatura': [np.nan, np.nan, np.nan, 28, 27,26]
})

df_temperaturas['preenchido_ffill'] = df_temperaturas['temperatura'].ffill()

df_temperaturas
# Out:
#    dia  temperatura  preenchido_ffill
# 0  Seg          NaN               NaN
# 1  Ter          NaN               NaN
# 2  Qua          NaN               NaN
# 3  Qui         28.0              28.0
# 4  Sex         27.0              27.0
# 5  Sab         26.0              26.0

# %%
# MEU CÓDIGO EXEMPLO ALUNOS DE ESCOLA (DADOS COMPLETOS)
df_cidades = pd.DataFrame({
    'nome': ['Davi', 'Julia', 'Maria', 'Gabriel', 'Fernanda'],
    'cidade': ['Areias', 'Bananal', 'Cunha', 'Silveiras', 'Arapeí'],
    'idade': [17,17,17,17,17],
    'ano':['3º ano','3º ano','3º ano','3º ano','3º ano']
})

df_cidades['cidade_corrigida'] = df_cidades['cidade'].fillna('Não informado')

df_cidades
# Out:
#        nome     cidade  idade     ano cidade_corrigida
# 0      Davi     Areias     17  3º ano           Areias
# 1     Julia    Bananal     17  3º ano          Bananal
# 2     Maria      Cunha     17  3º ano            Cunha
# 3   Gabriel  Silveiras     17  3º ano        Silveiras
# 4  Fernanda     Arapeí     17  3º ano           Arapeí

# %%
# MEU CÓDIGO EXEMPLO ALUNOS DE ESCOLA (DADOS INCOMPLETOS E FICTICIOS CIDADE DE JUIZ PEDRO)
df_bairros = pd.DataFrame({
    'nome': ['Ana', 'Beatriz', 'Cláuda', 'Daniela', 'Érica'],
    'região_cidade': ['Nodeste','Noroeste', 'Sudeste','Sudoeste','Centro'],
    'bairro':[np.nan, 'Chácaras Araujo', np.nan, np.nan, 'Chácaras Bauruenses'],
    'cargo': ['cientista de dados', 'engenheira de dados', 'chefe da divisão de dados', 'engenheira de dados', 'cientista de dados'],
    'salario':[5000.00,7500.00,10000.00,7500.00,5110.00]
})

df_bairros['cidade_corrigida'] = df_bairros['bairro'].fillna('Não informado')

df_bairros
# Out:
#       nome região_cidade               bairro                      cargo  \
# 0      Ana       Nodeste                  NaN         cientista de dados
# 1  Beatriz      Noroeste      Chácaras Araujo        engenheira de dados
# 2   Cláuda       Sudeste                  NaN  chefe da divisão de dados
# 3  Daniela      Sudoeste                  NaN        engenheira de dados
# 4    Érica        Centro  Chácaras Bauruenses         cientista de dados
#
#    salario     cidade_corrigida
# 0   5000.0        Não informado
# 1   7500.0      Chácaras Araujo
# 2  10000.0        Não informado
# 3   7500.0        Não informado
# 4   5110.0  Chácaras Bauruenses

# %%
# MEU CÓDIGO EXEMPLO QUADRO DE FUNCIONARIOS DA EMPRESA TECXITA (DADOS INCOMPELTO)
# CREDITOS GOOGLE GEMINI, ESTE FOI MEIO QUE NÃO INTENSIONAL...
import pandas as pd
import numpy as np
import plotly.express as px

# 1. Criação dos dados de Cidades
df_cidades = pd.DataFrame({
    'nome': ['José (PO)', 'João (CEO)', 'Juca','José (Master)', 'João', 'André', 'Casdine', 'João Pedro', 'Neymar', 'Aléx', 'Bruna', 'Cássia', 'Debora', 'Jennifer', 'Isabela','Pina'],
    'cidade': ['Areias', 'Bananal', 'Cunha', 'Silveiras', 'Arapeí','Areias', 'Bananal', 'Cunha', 'Silveiras', 'Arapeí','Areias', 'Bananal', 'Cunha', 'Silveiras', 'Arapeí', np.nan]
})

# 2. Criação dos dados de Salários
df_salarios = pd.DataFrame({
    'salario_hora': [30.30, 340.00, 80.99, 30.60, 80.99, 40.79, 40.79, 40.79, 40.00, 50.50, 60.50, np.nan, np.nan, np.nan, np.nan, np.nan]
})

# 3. Tratamento de Dados (Preenchimento)
df_cidades['cidade'] = df_cidades['cidade'].fillna('Não informado')
df_salarios['salario_limpo'] = df_salarios['salario_hora'].ffill() # Preenche os nulos com o último valor válido

# 4. União das tabelas para que o Plotly enxergue tudo junto
df_final = pd.concat([df_cidades, df_salarios['salario_limpo']], axis=1)

# 5. Geração do Gráfico com Cores por Cidade
fig = px.bar(df_final,
             x='nome',
             y='salario_limpo',
             color='cidade',  # <--- ISSO garante uma cor diferente para cada cidade declarada
             title='Média Salarial por Funcionário e Cidade (Tecxita)',
             labels={'nome': 'Funcionário', 'salario_limpo': 'Salário/Hora', 'cidade': 'Cidade'},
             template='plotly_white') # Garante que o fundo não interfira nas cores

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# EXEMPLIO USANDO A BIBLIOTECA PLOTLY POREM USANDO CORES (Creditos Google Gemini)
import plotly.express as px

# 1. Preparação dos dados
senioridade_media_salario = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

# 2. Criação do gráfico com ajustes de cor e tema
fig = px.bar(senioridade_media_salario,
             x='senioridade',
             y='usd',
             color='senioridade',  # O segredo continua aqui
             title='Média Salarial por Senioridade',
             labels={'senioridade': 'Nível de Senioridade', 'usd': 'Média Salarial (USD)'},
             template='plotly_white') # Força um fundo branco para destacar as cores

# 3. Exibição
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **DESAFIO**

# %%
# Desafio realizado antes de acompanhar a aula 4
import plotly.express as px

# 1. Filtrar apenas por 'Data Scientist'
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']

# 2. Agrupar por país e calcular a média salarial
# Usaremos a coluna 'usd' para manter a base comparativa mundial
salario_por_pais = df_ds.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

# 3. Criar o gráfico de barras
fig = px.bar(salario_por_pais,
             x='residencia',
             y='usd',
             color='residencia', # Cada país terá uma cor única
             title='Média Salarial Anual de Data Scientists por País (USD)',
             labels={'residencia': 'Sigla do País', 'usd': 'Média Salarial (USD)'},
             color_discrete_sequence=px.colors.qualitative.Bold) # Paleta de cores vibrantes

# Melhorando o layout para as siglas dos países ficarem legíveis
fig.update_layout(xaxis_tickangle=-45)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install pycountry

# %%
# Desafio realizado antes de acompanhar a aula 4
import plotly.express as px

# 1. Filtrar apenas por 'Data Scientist'
df_ds = df_limpo[df_limpo['cargo'] == 'Data Engineer']

# 2. Agrupar por país e calcular a média salarial
# Usaremos a coluna 'usd' para manter a base comparativa mundial
salario_por_pais = df_ds.groupby('residencia')['usd'].mean().sort_values(ascending=False).reset_index()

# 3. Criar o gráfico de barras
fig = px.bar(salario_por_pais,
             x='residencia',
             y='usd',
             color='residencia', # Cada país terá uma cor única
             title='Média Salarial Anual de Data Engineer por País (USD)',
             labels={'residencia': 'Sigla do País', 'usd': 'Média Salarial (USD)'},
             color_discrete_sequence=px.colors.qualitative.Bold) # Paleta de cores vibrantes

# Melhorando o layout para as siglas dos países ficarem legíveis
fig.update_layout(xaxis_tickangle=-45)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# MESMO DESAFIO, POREM CONVERTIDO PARA REAIS
import plotly.express as px

# 1. Definir a cotação
cotacao_usd_brl = 5.26 # Você pode ajustar esse valor (Valor de 30/01/2026 as 19:21)

# 2. Filtrar e Criar a coluna em Reais
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist'].copy()
df_ds['salario_brl'] = df_ds['usd'] * cotacao_usd_brl

# 3. Agrupar por país e calcular a média em BRL
salario_por_pais = df_ds.groupby('residencia')['salario_brl'].mean().sort_values(ascending=False).reset_index()

# 4. Criar o gráfico de barras
fig = px.bar(salario_por_pais,
             x='residencia',
             y='salario_brl',
             color='residencia',
             title=f'Média Salarial Anual de Data Scientists por País (Conversão: R$ {cotacao_usd_brl:.2f})',
             labels={'residencia': 'País de Residência', 'salario_brl': 'Média Salarial (R$)'},
             color_discrete_sequence=px.colors.qualitative.Bold,
             text_auto='.2s') # Adiciona o valor resumido em cima das barras (ex: 500k)

# Ajustes estéticos
fig.update_layout(xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
